# %%
import pandas as pd

df = pd.read_csv(
    r'C:\Users\laksh\Desktop\Hotels_booking\fact_bookings.csv',
    usecols=[
        'property_id', 'booking_date', 'check_in_date', 'checkout_date',
        'no_guests', 'room_category', 'booking_platform', 'ratings_given',
        'booking_status', 'revenue_generated', 'revenue_realized', 'date',
        'mmm yy', 'week no', 'day_type'
    ],
    
    parse_dates=['booking_date', 'check_in_date', 'checkout_date','date'],
    dayfirst=True
)

# If you want to use 'property_id' as an index, you can do so after reading the CSV
#df.set_index('property_id', inplace=True)

# %%
df.head()
# Out:
#    property_id booking_date check_in_date checkout_date  no_guests  \
# 0        16558   2022-04-15    2022-05-05    2022-05-07          3
# 1        16558   2022-04-30    2022-05-05    2022-05-07          2
# 2        16558   2022-05-01    2022-05-05    2022-05-06          3
# 3        16558   2022-05-03    2022-05-05    2022-05-06          2
# 4        16558   2022-04-30    2022-05-05    2022-05-10          4
#
#   room_category booking_platform  ratings_given booking_status  \
# 0      Standard         tripster            5.0    Checked Out
# 1      Standard           others            NaN      Cancelled
# 2      Standard   direct offline            5.0    Checked Out
# 3      Standard         tripster            3.0    Checked Out
# 4      Standard           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized       date  mmm yy week no  day_type
# 0              10010             10010 2022-05-05  May-22    W 19  weekeday
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92581 entries, 0 to 92580
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   property_id        92581 non-null  int64
#  1   booking_date       92581 non-null  datetime64[ns]
#  2   check_in_date      92581 non-null  datetime64[ns]
#  3   checkout_date      92581 non-null  datetime64[ns]
#  4   no_guests          92581 non-null  int64
#  5   room_category      92581 non-null  object
#  6   booking_platform   92581 non-null  object
#  7   ratings_given      38924 non-null  float64
#  8   booking_status     92581 non-null  object
#  9   revenue_generated  92581 non-null  int64
#  10  revenue_realized   92581 non-null  int64
#  11  date               92581 non-null  datetime64[ns]
#  12  mmm yy             92581 non-null  object
#  13  week no            92581 non-null  object
#  14  day_type           92581 non-null  object
# ...

# %%
df.shape
# Out:
# (92581, 15)

# %%
df.head()
# Out:
#    property_id booking_date check_in_date checkout_date  no_guests  \
# 0        16558   2022-04-15    2022-05-05    2022-05-07          3
# 1        16558   2022-04-30    2022-05-05    2022-05-07          2
# 2        16558   2022-05-01    2022-05-05    2022-05-06          3
# 3        16558   2022-05-03    2022-05-05    2022-05-06          2
# 4        16558   2022-04-30    2022-05-05    2022-05-10          4
#
#   room_category booking_platform  ratings_given booking_status  \
# 0      Standard         tripster            5.0    Checked Out
# 1      Standard           others            NaN      Cancelled
# 2      Standard   direct offline            5.0    Checked Out
# 3      Standard         tripster            3.0    Checked Out
# 4      Standard           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized       date  mmm yy week no  day_type
# 0              10010             10010 2022-05-05  May-22    W 19  weekeday
# ...

# %%
df.describe()
# Out:
#         property_id                   booking_date  \
# count  92581.000000                          92581
# mean   18061.071818  2022-06-14 16:54:23.840312576
# min    16558.000000            2022-04-11 00:00:00
# 25%    17558.000000            2022-05-22 00:00:00
# 50%    17564.000000            2022-06-16 00:00:00
# 75%    18563.000000            2022-07-10 00:00:00
# max    19563.000000            2022-07-31 00:00:00
# std     1092.814020                            NaN
#
#                        check_in_date                  checkout_date  \
# count                          92581                          92581
# mean   2022-06-18 14:50:06.344714240  2022-06-20 19:09:17.803436544
# min              2022-05-05 00:00:00            2022-05-06 00:00:00
# 25%              2022-05-25 00:00:00            2022-05-28 00:00:00
# 50%              2022-06-19 00:00:00            2022-06-21 00:00:00
# 75%              2022-07-14 00:00:00            2022-07-17 00:00:00
# ...

# %%
df.columns
# Out:
# Index(['property_id', 'booking_date', 'check_in_date', 'checkout_date',
#        'no_guests', 'room_category', 'booking_platform', 'ratings_given',
#        'booking_status', 'revenue_generated', 'revenue_realized', 'date',
#        'mmm yy', 'week no', 'day_type'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# property_id              0
# booking_date             0
# check_in_date            0
# checkout_date            0
# no_guests                0
# room_category            0
# booking_platform         0
# ratings_given        53657
# booking_status           0
# revenue_generated        0
# revenue_realized         0
# date                     0
# mmm yy                   0
# week no                  0
# day_type                 0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 92576    False
# 92577    False
# 92578    False
# 92579    False
# 92580    False
# Length: 92581, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 988

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (91593, 15)

# %%
import numpy as np
# Select only the numeric columns of the DataFrame
numeric_df = df.select_dtypes(include=[np.number])

# Now, you can calculate the correlation matrix
corr_matrix = numeric_df.corr()
print(corr_matrix)
# Out:
#                    property_id  no_guests  ratings_given  revenue_generated  \
# property_id           1.000000   0.010616      -0.071434          -0.125471
# no_guests             0.010616   1.000000       0.001358           0.217732
# ratings_given        -0.071434   0.001358       1.000000           0.001682
# revenue_generated    -0.125471   0.217732       0.001682           1.000000
# revenue_realized     -0.100745   0.173165      -0.061534           0.794497
# date_year                  NaN        NaN            NaN                NaN
# date_month           -0.001394   0.001766       0.000052           0.000141
#
#                    revenue_realized  date_year  date_month
# property_id               -0.100745        NaN   -0.001394
# no_guests                  0.173165        NaN    0.001766
# ratings_given             -0.061534        NaN    0.000052
# revenue_generated          0.794497        NaN    0.000141
# revenue_realized           1.000000        NaN   -0.000129
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a copy of the DataFrame to avoid the SettingWithCopyWarning
df_copy = df.copy()

# Convert 'day_type' to categorical type
df_copy['day_type'] = df_copy['day_type'].astype('category')

# Create the countplot
sns.countplot(data=df_copy, x='day_type')
plt.show()

# %%
df_copy['room_category'] = df_copy['room_category'].astype('category')

# Create the countplot
sns.countplot(data=df_copy, x='room_category')
plt.show()

# %%
df_copy['booking_platform'] = df_copy['booking_platform'].astype('category')

# Create the countplot
# sns.countplot(data=df_copy, x='booking_platform')

fg , ax = plt.subplots(figsize=(10,6))
ax.bar(df_copy['booking_platform'].value_counts().index,df_copy['booking_platform'].astype('category').value_counts())

plt.show()

# %%
df_copy['booking_status'] = df_copy['booking_status'].astype('category')

# Create the countplot
sns.countplot(data=df_copy, x='booking_status')
plt.show()

# %%
df_copy['booking_platform'].value_counts().index
# Out:
# CategoricalIndex(['others', 'makeyourtrip', 'logtrip', 'direct online',
#                   'tripster', 'journey', 'direct offline'],
#                  categories=['direct offline', 'direct online', 'journey', 'logtrip', 'makeyourtrip', 'others', 'tripster'], ordered=False, dtype='category', name='booking_platform')

# %%
df['booking_status'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['booking_platform'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['room_category'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['day_type'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df['no_guests'])
# Out:
# (array([29790.,     0., 41097.,     0., 10485.,     0.,  8236.,     0.,
#           961.,  1024.]),
#  array([1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['ratings_given'])
# Out:
# (array([ 2430.,     0.,  4434.,     0.,     0., 11973.,     0.,  6567.,
#             0., 13215.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['revenue_generated'])
# Out:
# (array([23648., 26808., 20214., 11019.,  2048.,  3565.,  3108.,   668.,
#           294.,   221.]),
#  array([ 6500., 10372., 14244., 18116., 21988., 25860., 29732., 33604.,
#         37476., 41348., 45220.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['revenue_realized'])
# Out:
# (array([20435., 24542., 23937., 10167.,  6058.,  1788.,  3786.,   428.,
#           284.,   168.]),
#  array([ 2600.,  6862., 11124., 15386., 19648., 23910., 28172., 32434.,
#         36696., 40958., 45220.]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(df['no_guests'])
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3673073241.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['no_guests'])
# <Axes: xlabel='no_guests', ylabel='Density'>

# %%
sns.distplot(df['ratings_given'])
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\1624674656.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ratings_given'])
# <Axes: xlabel='ratings_given', ylabel='Density'>

# %%
sns.distplot(df['revenue_realized'])
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3084697744.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['revenue_realized'])
# <Axes: xlabel='revenue_realized', ylabel='Density'>

# %%
sns.distplot(df['revenue_generated'])
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\1820028785.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['revenue_generated'])
# <Axes: xlabel='revenue_generated', ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.boxplot(data=df, x='no_guests')
plt.show()

# %%
sns.boxplot(data=df, x='ratings_given')
plt.show()

# %%
sns.boxplot(data=df, x='revenue_generated')
plt.show()

# %%
sns.boxplot(data=df, x='revenue_realized')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.scatterplot(x='room_category', y='no_guests', data=df,hue=df['day_type'])
plt.show()

# %%
sns.scatterplot(x='room_category', y='ratings_given', data=df,hue=df['day_type'])
plt.show()

# %%
sns.barplot(x='room_category', y='ratings_given', data=df,hue=df['day_type'])
plt.show()

# %%
sns.barplot(x='room_category', y='no_guests', data=df,hue=df['day_type'])
plt.show()

# %%
sns.barplot(x='room_category', y='revenue_generated', data=df,hue=df['day_type'])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you've already read the DataFrame df
df.loc[:, 'day_type'] = df['day_type'].astype('category')

# Create a boxplot
sns.boxplot(x='day_type', y='no_guests', data=df)
plt.show()

# %%
# Assuming you've already read the DataFrame df
df.loc[:, 'day_type'] = df['day_type'].astype('category')

# Create a boxplot
sns.boxplot(x='day_type', y='ratings_given', data=df)
plt.show()

# %%
df.reset_index(drop=True, inplace=True)
df = df[~df.index.duplicated(keep='first')]
sns.pairplot(df,hue='room_category')
# Out:
# C:\Users\laksh\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x='date', y='revenue_generated', data=df)
plt.show()

# %%
sns.boxplot(x='check_in_date', y='revenue_generated', data=df)
plt.show()

# %%
sns.boxplot(x='booking_date', y='revenue_generated', data=df)
plt.show()

# %%
sns.lineplot(x='date', y='revenue_generated', data=df)
plt.show()

# %%
sns.lineplot(x='booking_date', y='revenue_generated', data=df)
plt.show()

# %%
neumeric_feature = ['property_id','no_guests','ratings_given','revenue_generated','revenue_realized']
matrix = df[neumeric_feature].corr()
sns.heatmap(matrix,annot=True)
# Out:
# <Axes: >

# %%
neumeric_feature = ['property_id','no_guests','ratings_given','revenue_generated','revenue_realized']
matrix = df[neumeric_feature].corr()
sns.clustermap(matrix)

# %%
ratings_median = df['ratings_given'].median()
df['ratings_given'].fillna(ratings_median, inplace=True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.boxplot(df['revenue_generated'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['revenue_realized'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['ratings_given'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['property_id'])
# Out:
# <Axes: >

# %%
df.sample(5)
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 82543        19563   2022-07-21    2022-07-24    2022-07-28          1
# 74683        19560   2022-07-18    2022-07-18    2022-07-19          1
# 8190         16559   2022-05-13    2022-05-15    2022-05-19          2
# 61598        19560   2022-06-24    2022-06-30    2022-07-02          1
# 46602        19558   2022-06-16    2022-06-19    2022-06-22          2
#
#       room_category booking_platform  ratings_given booking_status  \
# 82543      Standard          journey            2.0    Checked Out
# 74683      Preminum    direct online            4.0    Checked Out
# 8190       Preminum         tripster            4.0      Cancelled
# 61598      Preminum          logtrip            5.0    Checked Out
# 46602      Standard     makeyourtrip            4.0    Checked Out
#
#        revenue_generated  revenue_realized       date  mmm yy week no  \
# ...

# %%
df['week no'].unique()
# Out:
# array(['W 19', 'W 24', 'W 28', 'W 20', 'W 21', 'W 22', 'W 23', 'W 25',
#        'W 26', 'W 27', 'W 29', 'W 30', 'W 31', 'W 32'], dtype=object)

# %%
df['mmm yy'].unique()
# Out:
# array(['May-22', 'Jun-22', 'Jul-22'], dtype=object)

# %%
df['date'].unique()
# Out:
# <DatetimeArray>
# ['2022-05-05 00:00:00', '2022-06-05 00:00:00', '2022-07-05 00:00:00',
#  '2022-05-13 00:00:00', '2022-05-14 00:00:00', '2022-05-15 00:00:00',
#  '2022-05-16 00:00:00', '2022-05-17 00:00:00', '2022-05-18 00:00:00',
#  '2022-05-19 00:00:00', '2022-05-20 00:00:00', '2022-05-21 00:00:00',
#  '2022-05-22 00:00:00', '2022-05-23 00:00:00', '2022-05-24 00:00:00',
#  '2022-05-25 00:00:00', '2022-05-26 00:00:00', '2022-05-27 00:00:00',
#  '2022-05-28 00:00:00', '2022-05-29 00:00:00', '2022-05-30 00:00:00',
#  '2022-05-31 00:00:00', '2022-05-06 00:00:00', '2022-06-06 00:00:00',
#  '2022-07-06 00:00:00', '2022-06-13 00:00:00', '2022-06-14 00:00:00',
#  '2022-06-15 00:00:00', '2022-06-16 00:00:00', '2022-06-17 00:00:00',
#  '2022-06-18 00:00:00', '2022-06-19 00:00:00', '2022-06-20 00:00:00',
#  '2022-06-21 00:00:00', '2022-06-22 00:00:00', '2022-06-23 00:00:00',
#  '2022-06-24 00:00:00', '2022-06-25 00:00:00', '2022-06-26 00:00:00',
# ...

# %%
df['room_category'].unique()
# Out:
# array(['Standard', 'Elite', 'Preminum', 'Presidential'], dtype=object)

# %%
df['no_guests'].unique()
# Out:
# array([3, 2, 4, 1, 5, 6], dtype=int64)

# %%
df['ratings_given'].unique()
# Out:
# array([5., 4., 3., 1., 2.])

# %%
df['revenue_generated'].unique()
# Out:
# array([10010,  9100, 10920, 15120, 12600, 16800, 21840, 20160, 26600,
#        11050, 12155, 13260, 16830, 15300, 18360, 24480, 20400, 22440,
#        28560, 41990, 32300, 35530, 38760, 13860, 29260, 18480, 23520,
#        37240, 31920, 34580, 45220, 26520,  6500,  9000, 10800,  9900,
#        12000, 13200, 14400, 19000, 20900, 22800,  7150,  7800, 15600,
#        24700,  9750, 10725, 11700, 13500, 16200, 14850, 19800, 18000,
#        23400, 28500, 34200, 31350, 39900, 25200, 21600, 37050],
#       dtype=int64)

# %%
df['revenue_realized'].unique()
# Out:
# array([10010,  3640,  9100, 10920,  4004,  6048,  5040, 12600, 16800,
#        21840, 20160, 26600, 11050, 12155,  4420,  4862,  5304,  6732,
#        15300,  6120, 16830, 18360,  7344, 24480, 20400, 22440,  8160,
#        28560, 41990, 32300, 35530, 16796, 12920, 38760,  5544,  6720,
#        10640, 11704, 29260, 13860, 15120, 18480,  8064, 23520, 14896,
#         7392, 31920,  4368,  9408, 34580, 11424, 13260,  8976,  9792,
#        45220, 26520, 15504, 14212,  2600,  6500,  9000, 10800,  3600,
#         9900,  3960, 12000, 13200,  5760,  7600, 19000, 20900, 22800,
#         7150,  2860, 14400,  4800,  9120,  7800,  3120,  4320, 15600,
#        24700,  8360,  9750, 10725,  4680,  3900, 11700,  4290,  5400,
#        16200, 13500,  5940, 14850, 19800, 18000, 23400, 28500,  6480,
#         7200,  7920, 13680, 11400, 34200, 12540, 15960, 25200, 21600,
#        31350, 37050, 14820, 37240, 18088,  5280,  6240,  9880, 10080,
# ...

# %%
df['booking_date'].unique()
# Out:
# <DatetimeArray>
# ['2022-04-15 00:00:00', '2022-04-30 00:00:00', '2022-05-01 00:00:00',
#  '2022-05-03 00:00:00', '2022-04-29 00:00:00', '2022-05-02 00:00:00',
#  '2022-04-11 00:00:00', '2022-05-04 00:00:00', '2022-05-05 00:00:00',
#  '2022-04-28 00:00:00',
#  ...
#  '2022-07-22 00:00:00', '2022-07-23 00:00:00', '2022-07-24 00:00:00',
#  '2022-07-25 00:00:00', '2022-07-26 00:00:00', '2022-07-27 00:00:00',
#  '2022-07-28 00:00:00', '2022-07-29 00:00:00', '2022-07-30 00:00:00',
#  '2022-07-31 00:00:00']
# Length: 111, dtype: datetime64[ns]

# %%
df['check_in_date'].unique()
# Out:
# <DatetimeArray>
# ['2022-05-05 00:00:00', '2022-06-05 00:00:00', '2022-07-05 00:00:00',
#  '2022-05-13 00:00:00', '2022-05-14 00:00:00', '2022-05-15 00:00:00',
#  '2022-05-16 00:00:00', '2022-05-17 00:00:00', '2022-05-18 00:00:00',
#  '2022-05-19 00:00:00', '2022-05-20 00:00:00', '2022-05-21 00:00:00',
#  '2022-05-22 00:00:00', '2022-05-23 00:00:00', '2022-05-24 00:00:00',
#  '2022-05-25 00:00:00', '2022-05-26 00:00:00', '2022-05-27 00:00:00',
#  '2022-05-28 00:00:00', '2022-05-29 00:00:00', '2022-05-30 00:00:00',
#  '2022-05-31 00:00:00', '2022-05-06 00:00:00', '2022-06-06 00:00:00',
#  '2022-07-06 00:00:00', '2022-06-13 00:00:00', '2022-06-14 00:00:00',
#  '2022-06-15 00:00:00', '2022-06-16 00:00:00', '2022-06-17 00:00:00',
#  '2022-06-18 00:00:00', '2022-06-19 00:00:00', '2022-06-20 00:00:00',
#  '2022-06-21 00:00:00', '2022-06-22 00:00:00', '2022-06-23 00:00:00',
#  '2022-06-24 00:00:00', '2022-06-25 00:00:00', '2022-06-26 00:00:00',
# ...

# %%
df['checkout_date'].unique()
# Out:
# <DatetimeArray>
# ['2022-05-07 00:00:00', '2022-05-06 00:00:00', '2022-05-10 00:00:00',
#  '2022-05-11 00:00:00', '2022-05-08 00:00:00', '2022-05-09 00:00:00',
#  '2022-05-12 00:00:00', '2022-05-13 00:00:00', '2022-05-15 00:00:00',
#  '2022-05-14 00:00:00', '2022-05-19 00:00:00', '2022-05-18 00:00:00',
#  '2022-05-17 00:00:00', '2022-05-16 00:00:00', '2022-05-20 00:00:00',
#  '2022-05-21 00:00:00', '2022-05-22 00:00:00', '2022-05-23 00:00:00',
#  '2022-05-24 00:00:00', '2022-05-25 00:00:00', '2022-05-26 00:00:00',
#  '2022-05-27 00:00:00', '2022-05-28 00:00:00', '2022-05-29 00:00:00',
#  '2022-05-30 00:00:00', '2022-05-31 00:00:00', '2022-06-01 00:00:00',
#  '2022-06-02 00:00:00', '2022-06-03 00:00:00', '2022-06-04 00:00:00',
#  '2022-06-05 00:00:00', '2022-06-06 00:00:00', '2022-06-07 00:00:00',
#  '2022-06-11 00:00:00', '2022-06-08 00:00:00', '2022-06-09 00:00:00',
#  '2022-06-10 00:00:00', '2022-06-12 00:00:00', '2022-06-13 00:00:00',
# ...

# %%
df['booking_status'].unique()
# Out:
# array(['Checked Out', 'Cancelled', 'No Show'], dtype=object)

# %%
df['booking_platform'].unique()
# Out:
# array(['tripster', 'others', 'direct offline', 'makeyourtrip', 'logtrip',
#        'journey', 'direct online'], dtype=object)

# %%
df['day_type'].unique()
# Out:
# array(['weekeday', 'weekend'], dtype=object)

# %%
df['property_id'].unique()
# Out:
# array([16558, 16559, 16560, 16561, 16562, 16563, 17558, 17559, 17560,
#        17561, 17562, 17563, 18558, 18559, 18560, 18561, 18562, 18563,
#        19558, 19559, 19560, 19561, 19562, 19563, 17564], dtype=int64)

# %%
df['week_no'] = df['week no'].str.extract('(\d+)')

# %%
df.head()
# Out:
#    property_id booking_date check_in_date checkout_date  no_guests  \
# 0        16558   2022-04-15    2022-05-05    2022-05-07          3
# 1        16558   2022-04-30    2022-05-05    2022-05-07          2
# 2        16558   2022-05-01    2022-05-05    2022-05-06          3
# 3        16558   2022-05-03    2022-05-05    2022-05-06          2
# 4        16558   2022-04-30    2022-05-05    2022-05-10          4
#
#   room_category booking_platform  ratings_given booking_status  \
# 0      Standard         tripster            5.0    Checked Out
# 1      Standard           others            4.0      Cancelled
# 2      Standard   direct offline            5.0    Checked Out
# 3      Standard         tripster            3.0    Checked Out
# 4      Standard           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized       date  mmm yy week no  day_type  \
# 0              10010             10010 2022-05-05  May-22    W 19  weekeday
# ...

# %%
df['date_year'] = df['date'].dt.year
df.sample(5)
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 30522        19562   2022-05-25    2022-05-30    2022-06-03          2
# 54601        16561   2022-06-22    2022-06-26    2022-06-27          6
# 45999        17561   2022-06-18    2022-06-19    2022-06-21          1
# 52623        19563   2022-06-24    2022-06-24    2022-06-25          1
# 38618        18558   2022-06-09    2022-06-14    2022-06-19          2
#
#       room_category booking_platform  ratings_given booking_status  \
# 30522      Standard          logtrip            4.0      Cancelled
# 54601  Presidential         tripster            4.0    Checked Out
# 45999      Standard           others            4.0        No Show
# 52623      Standard     makeyourtrip            4.0      Cancelled
# 38618      Preminum    direct online            4.0    Checked Out
#
#        revenue_generated  revenue_realized       date  mmm yy week no  \
# ...

# %%
df['date_month'] = df['date'].dt.month
df.sample(5)
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 41268        17562   2022-06-13    2022-06-16    2022-06-17          4
# 72084        17564   2022-07-16    2022-07-16    2022-07-18          1
# 2924         16559   2022-04-16    2022-07-05    2022-05-08          2
# 15789        17558   2022-05-19    2022-05-21    2022-05-23          2
# 81782        17563   2022-07-18    2022-07-24    2022-07-27          2
#
#       room_category booking_platform  ratings_given booking_status  \
# 41268      Preminum           others            4.0      Cancelled
# 72084         Elite          logtrip            4.0      Cancelled
# 2924   Presidential    direct online            5.0    Checked Out
# 15789      Standard     makeyourtrip            3.0    Checked Out
# 81782         Elite           others            4.0      Cancelled
#
#        revenue_generated  revenue_realized       date  mmm yy week no  \
# ...

# %%
df['date_month_name'] = df['date'].dt.month_name()
df.sample(5)
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 17796        17561   2022-05-18    2022-05-22    2022-05-28          2
# 72405        16563   2022-07-17    2022-07-17    2022-07-19          1
# 22350        17563   2022-05-25    2022-05-25    2022-05-26          1
# 13005        19562   2022-05-16    2022-05-18    2022-05-23          1
# 73431        19560   2022-07-15    2022-07-17    2022-07-18          3
#
#       room_category booking_platform  ratings_given booking_status  \
# 17796         Elite     makeyourtrip            4.0    Checked Out
# 72405      Standard           others            4.0    Checked Out
# 22350         Elite     makeyourtrip            4.0      Cancelled
# 13005         Elite    direct online            3.0    Checked Out
# 73431      Standard     makeyourtrip            4.0    Checked Out
#
#        revenue_generated  revenue_realized       date  mmm yy week no  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'check_in_date' is a datetime type, if not, you may need to convert it.
#df['check_in_date'] = pd.to_datetime(df['check_in_date'])

# Group by 'check_in_date' and calculate the sum of 'revenue_generated'
revenue_by_date = df.groupby('booking_date')['revenue_generated'].sum().reset_index()

# Plotting the line plot with the sum of 'revenue_generated' for each 'check_in_date'
sns.lineplot(x='booking_date', y='revenue_generated', data=revenue_by_date)
plt.show()

# %%
df.describe()
# Out:
#         property_id                   booking_date  \
# count  91593.000000                          91593
# mean   18061.093239  2022-06-14 16:27:06.255281408
# min    16558.000000            2022-04-11 00:00:00
# 25%    17558.000000            2022-05-22 00:00:00
# 50%    17564.000000            2022-06-16 00:00:00
# 75%    18563.000000            2022-07-10 00:00:00
# max    19563.000000            2022-07-31 00:00:00
# std     1092.990728                            NaN
#
#                        check_in_date                  checkout_date  \
# count                          91593                          91593
# mean   2022-06-18 14:53:55.295273728  2022-06-20 19:27:27.833349888
# min              2022-05-05 00:00:00            2022-05-06 00:00:00
# 25%              2022-05-25 00:00:00            2022-05-28 00:00:00
# 50%              2022-06-19 00:00:00            2022-06-21 00:00:00
# 75%              2022-07-14 00:00:00            2022-07-17 00:00:00
# ...

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['revenue_generated'],bins=10)

plt.figure(figsize=(16,5))
plt.subplot(1,2,2)
sns.distplot(df['revenue_realized'],bins=10)

plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sns.distplot(df['ratings_given'],bins=10)
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\1000122099.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['revenue_generated'],bins=10)
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\1000122099.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print("highest",df['revenue_generated'].mean() + 3*df['revenue_generated'].std())
print("lowest",df['revenue_generated'].mean() - 3*df['revenue_generated'].std())
# Out:
# highest 34318.12570888028
# lowest -4451.205311033282

# %%
df[(df['revenue_generated'] > 34229) | (df['revenue_generated'] < -4420)]
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 91           16559   2022-05-03    2022-05-05    2022-05-07          5
# 97           16559   2022-05-04    2022-05-05    2022-05-08          3
# 98           16559   2022-04-14    2022-05-05    2022-05-10          5
# 100          16559   2022-05-05    2022-05-05    2022-05-06          4
# 197          16561   2022-05-01    2022-05-05    2022-05-07          6
# ...            ...          ...           ...           ...        ...
# 91471        19562   2022-07-28    2022-07-31    2022-08-01          6
# 91473        19562   2022-07-10    2022-07-31    2022-08-06          5
# 91478        19562   2022-07-25    2022-07-31    2022-08-06          5
# 91584        17564   2022-07-31    2022-07-31    2022-08-01          4
# 91589        17564   2022-07-30    2022-07-31    2022-08-01          4
#
#       room_category booking_platform  ratings_given booking_status  \
# ...

# %%
print("highest",df['revenue_realized'].mean() + 3*df['revenue_realized'].std())
print("lowest",df['revenue_realized'].mean() - 3*df['revenue_realized'].std())
# Out:
# highest 33520.69234916639
# lowest -8088.356471970534

# %%
df[(df['revenue_realized'] > 33488) | (df['revenue_realized'] < -8085)]
# Out:
#        property_id booking_date check_in_date checkout_date  no_guests  \
# 91           16559   2022-05-03    2022-05-05    2022-05-07          5
# 97           16559   2022-05-04    2022-05-05    2022-05-08          3
# 100          16559   2022-05-05    2022-05-05    2022-05-06          4
# 317          16563   2022-05-04    2022-05-05    2022-05-06          5
# 376          17558   2022-05-03    2022-05-05    2022-05-07          3
# ...            ...          ...           ...           ...        ...
# 91337        19560   2022-07-31    2022-07-31    2022-08-01          6
# 91471        19562   2022-07-28    2022-07-31    2022-08-01          6
# 91478        19562   2022-07-25    2022-07-31    2022-08-06          5
# 91584        17564   2022-07-31    2022-07-31    2022-08-01          4
# 91589        17564   2022-07-30    2022-07-31    2022-08-01          4
#
#       room_category booking_platform  ratings_given booking_status  \
# ...

# %%
print("highest",df['ratings_given'].mean() + 3*df['ratings_given'].std())
print("lowest",df['ratings_given'].mean() - 3*df['ratings_given'].std())
# Out:
# highest 6.312647559924498
# lowest 1.3616506943089033

# %%
df[(df['ratings_given'] > 6) | (df['ratings_given'] < 1)]
# Out:
# Empty DataFrame
# Columns: [property_id, booking_date, check_in_date, checkout_date, no_guests, room_category, booking_platform, ratings_given, booking_status, revenue_generated, revenue_realized, date, mmm yy, week no, day_type, week_no, date_year, date_month, date_month_name]
# Index: []

# %%
df.shape
# Out:
# (91593, 19)

# %%
df['revenue_generated'].skew()
# Out:
# 1.3776467502120477

# %%
df['revenue_realized'].skew()
# Out:
# 1.1838708287256956

# %%
df['revenue_generated'].describe()
# Out:
# count    91593.000000
# mean     14933.460199
# std       6461.555170
# min       6500.000000
# 25%       9900.000000
# 50%      13500.000000
# 75%      18000.000000
# max      45220.000000
# Name: revenue_generated, dtype: float64

# %%
df['revenue_realized'].describe()
# Out:
# count    91593.000000
# mean     12716.167939
# std       6934.841470
# min       2600.000000
# 25%       7600.000000
# 50%      11700.000000
# 75%      15300.000000
# max      45220.000000
# Name: revenue_realized, dtype: float64

# %%
sns.boxplot(df['revenue_generated'])
# Out:
# <Axes: >

# %%
sns.boxplot(df['revenue_realized'])
# Out:
# <Axes: >

# %%
df['revenue_generated'].describe()
# Out:
# count    91593.000000
# mean     14933.460199
# std       6461.555170
# min       6500.000000
# 25%       9900.000000
# 50%      13500.000000
# 75%      18000.000000
# max      45220.000000
# Name: revenue_generated, dtype: float64

# %%
df.shape
# Out:
# (91593, 19)

# %%
per25 = df['revenue_generated'].quantile(0.25)
per75 = df['revenue_generated'].quantile(0.75)
iqr = per75 - per25
upper_limit = per75 + 1.5 * iqr
lower_limit = per25 - 1.5 * iqr
new_df = df.copy()
new_df['revenue_generated'] = np.where(
    new_df['revenue_generated'] > upper_limit,
    upper_limit,
    np.where(
        new_df['revenue_generated'] < lower_limit,
        lower_limit,
        new_df['revenue_generated']
    )
)

# %%
new_df.shape
# Out:
# (91593, 19)

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.distplot(df['revenue_generated'])

plt.subplot(2,2,2)
sns.boxplot(df['revenue_generated'])

plt.subplot(2,2,3)
sns.distplot(new_df['revenue_generated'])

plt.subplot(2,2,4)
sns.boxplot(new_df['revenue_generated'])

plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3227338020.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['revenue_generated'])
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3227338020.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
per_25 = df['revenue_realized'].quantile(0.25)
per_75 = df['revenue_realized'].quantile(0.75)
iqr1 = per_75 - per_25
upper_limit1 = per_75 + 1.5 * iqr1
lower_limit1 = per_25 - 1.5 * iqr1
new_df = df.copy()
new_df['revenue_realized'] = np.where(
    new_df['revenue_realized'] > upper_limit1,
    upper_limit1,
    np.where(
        new_df['revenue_realized'] < lower_limit1,
        lower_limit1,
        new_df['revenue_realized']
    )
)

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.distplot(df['revenue_realized'])

plt.subplot(2,2,2)
sns.boxplot(df['revenue_realized'])

plt.subplot(2,2,3)
sns.distplot(new_df['revenue_realized'])

plt.subplot(2,2,4)
sns.boxplot(new_df['revenue_realized'])

plt.show()
# Out:
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3167100953.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['revenue_realized'])
# C:\Users\laksh\AppData\Local\Temp\ipykernel_22760\3167100953.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
print(new_df.columns)
# Out:
# Index(['property_id', 'booking_date', 'check_in_date', 'checkout_date',
#        'no_guests', 'room_category', 'booking_platform', 'ratings_given',
#        'booking_status', 'revenue_generated', 'revenue_realized', 'date',
#        'mmm yy', 'week no', 'day_type', 'week_no', 'date_year', 'date_month',
#        'date_month_name'],
#       dtype='object')

# %%
new_df.head()
# Out:
#    property_id booking_date check_in_date checkout_date  no_guests  \
# 0        16558   2022-04-15    2022-05-05    2022-05-07          3
# 1        16558   2022-04-30    2022-05-05    2022-05-07          2
# 2        16558   2022-05-01    2022-05-05    2022-05-06          3
# 3        16558   2022-05-03    2022-05-05    2022-05-06          2
# 4        16558   2022-04-30    2022-05-05    2022-05-10          4
#
#   room_category booking_platform  ratings_given booking_status  \
# 0      Standard         tripster            5.0    Checked Out
# 1      Standard           others            4.0      Cancelled
# 2      Standard   direct offline            5.0    Checked Out
# 3      Standard         tripster            3.0    Checked Out
# 4      Standard           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized       date  mmm yy week no  day_type  \
# 0              10010           10010.0 2022-05-05  May-22    W 19  weekeday
# ...

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91593 entries, 0 to 91592
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   property_id        91593 non-null  int64
#  1   booking_date       91593 non-null  datetime64[ns]
#  2   check_in_date      91593 non-null  datetime64[ns]
#  3   checkout_date      91593 non-null  datetime64[ns]
#  4   no_guests          91593 non-null  int64
#  5   room_category      91593 non-null  object
#  6   booking_platform   91593 non-null  object
#  7   ratings_given      91593 non-null  float64
#  8   booking_status     91593 non-null  object
#  9   revenue_generated  91593 non-null  int64
#  10  revenue_realized   91593 non-null  float64
#  11  date               91593 non-null  datetime64[ns]
#  12  mmm yy             91593 non-null  object
#  13  week no            91593 non-null  object
#  14  day_type           91593 non-null  object
# ...

# %%
new_df.dtypes
# Out:
# property_id                   int64
# booking_date         datetime64[ns]
# check_in_date        datetime64[ns]
# checkout_date        datetime64[ns]
# no_guests                     int64
# room_category                object
# booking_platform             object
# ratings_given               float64
# booking_status               object
# revenue_generated             int64
# revenue_realized            float64
# date                 datetime64[ns]
# mmm yy                       object
# week no                      object
# day_type                     object
# week_no                      object
# date_year                     int32
# date_month                    int32
# date_month_name              object
# dtype: object

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# Assuming `new_df` is your pre-loaded DataFrame

# Define your feature columns
categorical_cols = ['room_category', 'booking_platform', 'booking_status', 'day_type', 'date_month_name']
numerical_cols = ['no_guests', 'ratings_given', 'revenue_realized', 'date_year', 'date_month']

# Define the target variable
target = 'revenue_generated'

# Prepare the features (X) and target (y)
X = new_df.drop(columns=[target])
y = new_df[target]

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0)

# Preprocessing for numerical data
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Preprocessing for categorical data
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Create a pipeline that combines the preprocessor with a RandomForestRegressor
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=0))
])

# Train the model
model_pipeline.fit(x_train, y_train)

# Predict
y_pred = model_pipeline.predict(x_test)

# Evaluation
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mse ** 0.5

# Print evaluation metrics
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 97.2408102250436
# Mean Squared Error: 273950.8579287876
# Root Mean Squared Error: 523.4031504765592
# R-squared: 0.9933368276958034

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler

# Assuming 'room_category', 'booking_platform', 'booking_status', 'day_type', 'date_month_name' are categorical
categorical_cols = ['room_category', 'booking_platform', 'booking_status', 'day_type', 'date_month_name']

# Assuming 'no_guests', 'ratings_given', 'revenue_realized', 'date_year', 'date_month' are numerical
numerical_cols = ['no_guests', 'ratings_given', 'revenue_realized', 'date_year', 'date_month']

# Separate the features and target variable
X = new_df.drop('revenue_generated', axis=1)
y = new_df['revenue_generated']

from sklearn.model_selection import train_test_split
# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# Numerical transformer with MinMaxScaler
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', MinMaxScaler())  # Use MinMaxScaler for normalization to [0, 1]
])

# Categorical transformer
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Create a pipeline that combines the preprocessor with a RandomForestRegressor
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=0))
])

# Train the model
model_pipeline.fit(x_train, y_train)

# Predict
y_pred = model_pipeline.predict(x_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mse ** 0.5

# Print evaluation metrics
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 98.86836152814476
# Mean Squared Error: 278433.3081307475
# Root Mean Squared Error: 527.6678009228415
# R-squared: 0.9932346376972276

# %%
print("training data",x_train)
print("training data of target variable",y_train)
print("test data",x_test)
print("test data",y_test)
y_pred.shape
x_test.shape
# Out:
# training data        property_id booking_date check_in_date checkout_date  no_guests  \
# 80486        18562   2022-07-20    2022-07-23    2022-07-24          2
# 84396        18559   2022-07-19    2022-07-26    2022-07-27          3
# 79448        16559   2022-07-21    2022-07-23    2022-07-24          2
# 43383        17564   2022-06-17    2022-06-17    2022-06-18          4
# 38866        18562   2022-06-09    2022-06-14    2022-06-15          2
# ...            ...          ...           ...           ...        ...
# 21243        18561   2022-05-18    2022-05-24    2022-05-27          3
# 45891        17559   2022-06-16    2022-06-19    2022-06-20          2
# 42613        17562   2022-06-11    2022-06-17    2022-06-20          3
# 43567        16559   2022-06-13    2022-06-18    2022-06-22          3
# 68268        18562   2022-07-08    2022-07-14    2022-07-19          2
#
#       room_category booking_platform  ratings_given booking_status  \
# ...

# %%
print(y)
# Out:
# 0        10010
# 1         9100
# 2        10010
# 3         9100
# 4        10920
#          ...
# 91588    32300
# 91589    38760
# 91590    32300
# 91591    32300
# 91592    32300
# Name: revenue_generated, Length: 91593, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the standard deviation of y
std_y = np.std(y)

# Calculate the variance of y
var_y = std_y ** 2

print("Variance of y:", var_y)

# Plot the variance as a horizontal line
plt.axhline(y=var_y, color='r', linestyle='-', label='Variance of y')

# Show the plot
plt.legend()
plt.show()
# Out:
# Variance of y: 41751239.37539974

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Scatter plot of actual vs predicted values
plt.figure(figsize=(12, 6))
sns.scatterplot(x=y_test, y=y_pred, label='Actual vs Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Scatter Plot of Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# Residual Plot with predicted line
residuals = y_test - y_pred

plt.figure(figsize=(12, 6))
sns.scatterplot(x=y_test, y=residuals.values, label='Residuals')  # Use .values to convert Series to ndarray
plt.axhline(0, color='red', linestyle='--', label='Zero Residuals')
plt.title('Residual Plot')
plt.xlabel('Actual Values')
plt.ylabel('Residuals')
plt.legend()
plt.show()

# %%
from sklearn.model_selection import cross_val_score, KFold

# Assuming 'room_category', 'booking_platform', 'booking_status', 'day_type', 'date_month_name' are categorical
categorical_cols = ['room_category', 'booking_platform', 'booking_status', 'day_type', 'date_month_name']

# Assuming 'no_guests', 'ratings_given', 'revenue_realized', 'date_year', 'date_month' are numerical
numerical_cols = ['no_guests', 'ratings_given', 'revenue_realized', 'date_year', 'date_month']

# Separate the features and target variable
X = new_df.drop('revenue_generated', axis=1)
y = new_df['revenue_generated']

# Bundle preprocessing for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])

# Create a pipeline that combines the preprocessor with a RandomForestRegressor
model_pipeline = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', RandomForestRegressor(random_state=0))
])

# Set up KFold cross-validation with 5 folds
kf = KFold(n_splits=5, shuffle=True, random_state=0)

# Perform cross-validation
cv_scores = cross_val_score(model_pipeline, X, y, cv=kf, scoring='neg_mean_squared_error')

# Convert the scores to positive since scikit-learn returns neg_mean_squared_error for maximization
cv_scores = -cv_scores

# Print the cross-validation scores
print("Cross-Validation Scores:", cv_scores)
print("Mean CV MSE:", np.mean(cv_scores))
# Out:
# Cross-Validation Scores: [284879.36705592 266059.88968202 278359.85584294 275853.04059895
#  295815.08214738]
# Mean CV MSE: 280193.44706544373

# %%
from sklearn.linear_model import LinearRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

categorical_cols = ['room_category', 'booking_platform', 'day_type','date','booking_date', 'check_in_date',
                    'checkout_date','booking_status', 'mmm yy', 'week no', 'day_type','date_month_name']

# Assuming the rest of the columns are numerical
numerical_cols = [col for col in x_train.columns if col not in categorical_cols]

# Create transformers for numerical and categorical columns
numerical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))
])

# Use ColumnTransformer to apply transformers to specific columns
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numerical_transformer, numerical_cols),
        ('cat', categorical_transformer, categorical_cols)
    ])


# Update the model in the pipeline to use LinearRegression
model_lr = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Split the data
x_train, x_test, y_train, y_test = train_test_split(df.drop('revenue_generated', axis=1), 
                                                    df['revenue_generated'], test_size=0.3, random_state=0)

# Fit the Linear Regression model
model_lr.fit(x_train, y_train)

# Predictions
y_pred_lr = model_lr.predict(x_test)

# Evaluation metrics for Linear Regression
mse_lr = mean_squared_error(y_test, y_pred_lr)
r2_lr = r2_score(y_test, y_pred_lr)
print(f'Mean Squared Error (Linear Regression): {mse_lr}')
print(f'R-squared (Linear Regression): {r2_lr}')
# Out:
# Mean Squared Error (Linear Regression): 2729122.1287391945
# R-squared (Linear Regression): 0.9336878906716004

# %%
import matplotlib.pyplot as plt

# Scatter plot of actual vs predicted values for Linear Regression
plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred_lr, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Scatter Plot of Actual vs Predicted Values (Linear Regression)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR

# Multiple Linear Regression
linear_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', LinearRegression())
])

# Support Vector Regressor (SVR)
svr_model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('regressor', SVR(kernel='linear'))  # You can choose a different kernel if needed
])

# Fit the models
linear_model.fit(x_train, y_train)
svr_model.fit(x_train, y_train)

# Predictions
y_pred_linear = linear_model.predict(x_test)
y_pred_svr = svr_model.predict(x_test)

# Evaluation metrics for Linear Regression
mse_linear = mean_squared_error(y_test, y_pred_linear)
r2_linear = r2_score(y_test, y_pred_linear)

# Evaluation metrics for SVR
mse_svr = mean_squared_error(y_test, y_pred_svr)
r2_svr = r2_score(y_test, y_pred_svr)

# Display evaluation metrics
print("Multiple Linear Regression:")
print(f'Mean Squared Error: {mse_linear}')
print(f'R-squared: {r2_linear}')

print("\nSupport Vector Regressor (SVR):")
print(f'Mean Squared Error: {mse_svr}')
print(f'R-squared: {r2_svr}')
# Out:
# Multiple Linear Regression:
# Mean Squared Error: 2729122.1287391945
# R-squared: 0.9336878906716004
#
# Support Vector Regressor (SVR):
# Mean Squared Error: 4263649.2530678855
# R-squared: 0.8964020069200772

# %%
import matplotlib.pyplot as plt

# Scatter plot for Multiple Linear Regression
plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred_linear, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Scatter Plot of Actual vs Predicted Values (Multiple Linear Regression)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# Scatter plot for Support Vector Regressor (SVR)
plt.figure(figsize=(12, 6))
plt.scatter(y_test, y_pred_svr, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Scatter Plot of Actual vs Predicted Values (SVR)')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot of actual vs predicted values
plt.figure(figsize=(18, 12))

# Scatter plot 1: Actual vs Predicted
plt.subplot(2, 2, 1)
sns.scatterplot(x=y_test, y=y_pred, label='Actual vs Predicted')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Random Forest Regressor: Scatter Plot of Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Scatter plot 2: Linear Regression
plt.subplot(2, 2, 2)
plt.scatter(y_test, y_pred_lr, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Linear Regression: Scatter Plot of Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Scatter plot 3: Multiple Linear Regression
plt.subplot(2, 2, 3)
plt.scatter(y_test, y_pred_linear, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('Multiple Linear Regression: Scatter Plot of Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Scatter plot 4: Support Vector Regressor (SVR)
plt.subplot(2, 2, 4)
plt.scatter(y_test, y_pred_svr, alpha=0.5)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], '--', color='red', label='Perfect Prediction')
plt.title('SVR: Scatter Plot of Actual vs Predicted Values')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

plt.tight_layout()  # Adjust layout for better spacing
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Results
models = ['Random Forest', 'Linear Regression', 'Multiple Linear Regression', 'SVR']
mse_values = [283799.43, 2722343.38, 2722343.38, 4294645.23]
r2_values = [0.9932, 0.9347, 0.9347, 0.8970]

# Plotting MSE values
plt.figure(figsize=(12, 8))
plt.subplot(1, 2, 1)
plt.bar(models, mse_values, color=['blue', 'orange', 'green', 'red'])
plt.title('Mean Squared Error Comparison')
plt.ylabel('Mean Squared Error')
plt.ylim(0, max(mse_values) * 1.2)

# Plotting R-squared values
plt.subplot(1, 2, 2)
plt.bar(models, r2_values, color=['blue', 'orange', 'green', 'red'])
plt.title('R-squared Comparison')
plt.ylabel('R-squared')
plt.ylim(0, 1)  # R-squared values range from 0 to 1

plt.subplots_adjust(wspace=0.2)  # Increase horizontal spacing
plt.show()
